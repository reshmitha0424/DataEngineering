-- %%
select * from ecomm.silver.orders
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
select * from ecomm.silver.orders
where customer_id = 5816
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
select date_format(transaction_timestamp, 'yyyy-MM') as Order_month, 
customer_id, 
count(*) as Count_T,
Sum(quantity) as Item_count,
Sum(price*quantity) as total_amount_1,
Sum(total_amount) as total_amount
from ecomm.silver.orders
group by Order_month, customer_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- ...

-- %%
create or replace table ecomm.gold.orders_monthly_agg as
select date_format(transaction_timestamp, 'yyyy-MM') as Order_month, 
customer_id, 
count(*) as Count_T,
Sum(quantity) as Item_count,
Sum(price*quantity) as total_amount_1,
Sum(total_amount) as total_amount
from ecomm.silver.orders
group by Order_month, customer_id
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody></tbody></table></div>
